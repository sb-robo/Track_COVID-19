# %% [markdown]
# ### Import Dependencies

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../Dataset/COVID-data.csv')

# We will consider cases for INDIA only
df = df[df.location == 'India'].reset_index()
df.head()
# Out:
#    index iso_code continent location        date  total_cases  new_cases  \
# 0  24935      IND      Asia    India  2020-01-30          1.0        1.0
# 1  24936      IND      Asia    India  2020-01-31          1.0        0.0
# 2  24937      IND      Asia    India  2020-02-01          1.0        0.0
# 3  24938      IND      Asia    India  2020-02-02          2.0        1.0
# 4  24939      IND      Asia    India  2020-02-03          3.0        1.0
#
#    new_cases_smoothed  total_deaths  new_deaths  ...  gdp_per_capita  \
# 0                 NaN           NaN         NaN  ...        6426.674
# 1                 NaN           NaN         NaN  ...        6426.674
# 2                 NaN           NaN         NaN  ...        6426.674
# 3                 NaN           NaN         NaN  ...        6426.674
# 4                 NaN           NaN         NaN  ...        6426.674
#
#    extreme_poverty  cardiovasc_death_rate  diabetes_prevalence  \
# ...

# %%
#drop unnecessaily columns

df.isnull().sum()
# Out:
# index                                      0
# iso_code                                   0
# continent                                  0
# location                                   0
# date                                       0
# total_cases                                0
# new_cases                                  0
# new_cases_smoothed                         5
# total_deaths                              41
# new_deaths                                41
# new_deaths_smoothed                        5
# total_cases_per_million                    0
# new_cases_per_million                      0
# new_cases_smoothed_per_million             5
# total_deaths_per_million                  41
# new_deaths_per_million                    41
# new_deaths_smoothed_per_million            5
# reproduction_rate                         60
# icu_patients                             360
# icu_patients_per_million                 360
# hosp_patients                            360
# ...

# %%
drop_col = ['index', 'iso_code', 'continent', 'location', 'reproduction_rate',
            'icu_patients', 'icu_patients_per_million', 'hosp_patients',
            'hosp_patients_per_million', 'weekly_icu_admissions',
            'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
            'weekly_hosp_admissions_per_million', 'total_vaccinations',
            'new_vaccinations', 'total_vaccinations_per_hundred',
            'new_vaccinations_smoothed', 'stringency_index', 'gdp_per_capita', 
            'extreme_poverty', 'cardiovasc_death_rate', 'diabetes_prevalence', 
            'female_smokers', 'male_smokers', 'handwashing_facilities', 
            'hospital_beds_per_thousand', 'human_development_index']

df = df.drop(drop_col, axis=1)
df.head()
# Out:
#          date  total_cases  new_cases  new_cases_smoothed  total_deaths  \
# 0  2020-01-30          1.0        1.0                 NaN           NaN
# 1  2020-01-31          1.0        0.0                 NaN           NaN
# 2  2020-02-01          1.0        0.0                 NaN           NaN
# 3  2020-02-02          2.0        1.0                 NaN           NaN
# 4  2020-02-03          3.0        1.0                 NaN           NaN
#
#    new_deaths  new_deaths_smoothed  total_cases_per_million  \
# 0         NaN                  NaN                    0.001
# 1         NaN                  NaN                    0.001
# 2         NaN                  NaN                    0.001
# 3         NaN                  NaN                    0.001
# 4         NaN                  NaN                    0.002
#
#    new_cases_per_million  new_cases_smoothed_per_million  ...  positive_rate  \
# 0                  0.001                             NaN  ...            NaN
# ...

# %%
#save dataset
df.to_csv('../Dataset/India.csv',index=False)
